# %% [markdown]
# # Groundwater Flow Simulation using Finite Difference Method (Implicit Scheme)

# %% [markdown]
# This notebook simulates groundwater flow in a 2D confined aquifer using the implicit finite difference method. It visualizes the head distribution over time and includes animation.

# %% [markdown]
# ## 1. Import Required Libraries

# %%
import numpy as np
from scipy import linalg
import matplotlib.pyplot as plt
import matplotlib.animation
import matplotlib.animation as animation

# %% [markdown]
# ## 2. Define Helper Function for closet node number

# %% [markdown]
# This function finds the closest node in the grid given a coordinate.

# %%
def closest_node(node, nodes):
    nodes = np.asarray(nodes)
    deltas = nodes - node
    dist_2 = np.einsum('ij,ij->i', deltas, deltas)  # Compute squared distance
    return np.argmin(dist_2)  # Return index of closest node

# %% [markdown]
# ## 3. Define Problem Parameters

# %%
# Domain size
Lx, Ly = 2000, 2000   # Length in x and y direction (meters)

# Grid resolution
delx, dely = 100, 100  # Grid spacing (meters)

# Aquifer properties
T = 500    # Transmissivity (m²/day)
S = 0.001  # Storage coefficient (dimensionless)
Q = 0.05   # Injection rate (m³/day)

# Time settings
t_total = 365  # Total simulation time (days)
delt = 1      # Time step (days) - must be small for numerical stability

# %% [markdown]
# ## 4. Create Node Grid

# %% [markdown]
# Each node represents a point where we calculate the hydraulic head.

# %%
# Compute number of nodes
n_nodes_x = int(Lx / delx) + 1  # Nodes in x-direction
n_nodes_y = int(Ly / dely) + 1  # Nodes in y-direction
numnodes = n_nodes_x * n_nodes_y  # Total number of nodes

# Generate node coordinates
nodes = np.array([[i * delx, j * dely] for i in range(n_nodes_x) for j in range(n_nodes_y)])

# %% [markdown]
# ## 5. Identify Boundary Nodes

# %% [markdown]
# We assume a constant head on the left and right boundaries.

# %%
# Identify boundary node indices
left = np.arange(0, n_nodes_x, 1)
right = np.arange(numnodes - n_nodes_y, numnodes, 1)
bottom = np.arange(n_nodes_y, numnodes - n_nodes_y - 1, n_nodes_y)
top = np.arange(2 * n_nodes_y - 1, numnodes - 1, n_nodes_y)
boundary = np.concatenate((left, right, top, bottom), axis=0)

# %% [markdown]
# ## 6. Initialize Head Values

# %%
# Initialize hydraulic head (h) at all nodes
h_old = np.zeros(numnodes) + 100  # Initial condition (100m everywhere)

# Apply boundary conditions
h_old[left] = 100  # Fixed head on left boundary
h_old[right] = 100  # Fixed head on right boundary

# %% [markdown]
# ## 7. Solve for Head Distribution Over Time

# %% [markdown]
# We use the implicit finite difference method and solve the linear system at each time step

# %%
# Store head values over time
head_history = []
time_history = []

# Start time loop
t = 0.0
while t <= t_total:
    print(f"Time Step: {t} days")
    
    # Define coefficient matrix A and right-hand side vector b
    A = np.zeros((numnodes, numnodes))
    b = np.zeros(numnodes)

    # Loop over all nodes
    for i in range(numnodes):
        x, y = nodes[i]  # Get node coordinates

        # Set diagonal term in matrix A
        A[i, i] = 4 * T * delt / (S * delx**2) + 1
        b[i] = h_old[i]

        # Interior nodes: Apply finite difference approximation
        if i not in boundary:
            north = closest_node([x, y + dely], nodes)
            south = closest_node([x, y - dely], nodes)
            east = closest_node([x + delx, y], nodes)
            west = closest_node([x - delx, y], nodes)

            # Set coefficients for finite difference method
            A[i, north] = A[i, south] = A[i, east] = A[i, west] = -T * delt / (delx**2 * S)

        # Special case for top boundary
        if i in top:
            south = closest_node([x, y - dely], nodes)
            east = closest_node([x + delx, y], nodes)
            west = closest_node([x - delx, y], nodes)
            A[i, south] = -2 * T * delt / (delx**2 * S)
            A[i, east] = A[i, west] = -T * delt / (delx**2 * S)

        # Special case for bottom boundary
        if i in bottom:
            north = closest_node([x, y + dely], nodes)
            east = closest_node([x + delx, y], nodes)
            west = closest_node([x - delx, y], nodes)
            A[i, north] = -2 * T * delt / (delx**2 * S)
            A[i, east] = A[i, west] = -T * delt / (delx**2 * S)

    # Apply injection well
    well_idx = closest_node([1000, 1000], nodes)
    b[well_idx] += Q * delt / S  

    # Apply boundary conditions
    b[left] = 100
    A[left, left] = 1
    b[right] = 100
    A[right, right] = 1

    # Solve system of equations
    h = linalg.solve(A, b)

    # Store results
    head_history.append(h.copy())
    time_history.append(t)

    # Update for next time step
    h_old = h.copy()
    t += delt

# Convert results to NumPy arrays
head_history = np.array(head_history)
time_history = np.array(time_history)
# Out:
# Time Step: 0.0 days
# Time Step: 1.0 days
# Time Step: 2.0 days
# Time Step: 3.0 days
# Time Step: 4.0 days
# Time Step: 5.0 days
# Time Step: 6.0 days
# Time Step: 7.0 days
# Time Step: 8.0 days
# Time Step: 9.0 days
# Time Step: 10.0 days
# Time Step: 11.0 days
# Time Step: 12.0 days
# Time Step: 13.0 days
# Time Step: 14.0 days
# Time Step: 15.0 days
# Time Step: 16.0 days
# Time Step: 17.0 days
# Time Step: 18.0 days
# Time Step: 19.0 days
# Time Step: 20.0 days
# Time Step: 21.0 days
# Time Step: 22.0 days
# Time Step: 23.0 days
# Time Step: 24.0 days
# Time Step: 25.0 days
# Time Step: 26.0 days
# Time Step: 27.0 days
# Time Step: 28.0 days
# Time Step: 29.0 days
# Time Step: 30.0 days
# Time Step: 31.0 days
# Time Step: 32.0 days
# Time Step: 33.0 days
# Time Step: 34.0 days
# Time Step: 35.0 days
# Time Step: 36.0 days
# Time Step: 37.0 days
# Time Step: 38.0 days
# Time Step: 39.0 days
# Time Step: 40.0 days
# Time Step: 41.0 days
# Time Step: 42.0 days
# Time Step: 43.0 days
# Time Step: 44.0 days
# Time Step: 45.0 days
# Time Step: 46.0 days
# Time Step: 47.0 days
# Time Step: 48.0 days
# Time Step: 49.0 days
# Time Step: 50.0 days
# Time Step: 51.0 days
# Time Step: 52.0 days
# Time Step: 53.0 days
# Time Step: 54.0 days
# Time Step: 55.0 days
# Time Step: 56.0 days
# Time Step: 57.0 days
# Time Step: 58.0 days
# Time Step: 59.0 days
# Time Step: 60.0 days
# Time Step: 61.0 days
# Time Step: 62.0 days
# Time Step: 63.0 days
# Time Step: 64.0 days
# Time Step: 65.0 days
# Time Step: 66.0 days
# Time Step: 67.0 days
# Time Step: 68.0 days
# Time Step: 69.0 days
# Time Step: 70.0 days
# Time Step: 71.0 days
# Time Step: 72.0 days
# Time Step: 73.0 days
# Time Step: 74.0 days
# Time Step: 75.0 days
# Time Step: 76.0 days
# Time Step: 77.0 days
# Time Step: 78.0 days
# Time Step: 79.0 days
# Time Step: 80.0 days
# Time Step: 81.0 days
# Time Step: 82.0 days
# Time Step: 83.0 days
# Time Step: 84.0 days
# Time Step: 85.0 days
# Time Step: 86.0 days
# Time Step: 87.0 days
# Time Step: 88.0 days
# Time Step: 89.0 days
# Time Step: 90.0 days
# Time Step: 91.0 days
# Time Step: 92.0 days
# Time Step: 93.0 days
# Time Step: 94.0 days
# Time Step: 95.0 days
# Time Step: 96.0 days
# Time Step: 97.0 days
# Time Step: 98.0 days
# Time Step: 99.0 days
# Time Step: 100.0 days
# Time Step: 101.0 days
# Time Step: 102.0 days
# Time Step: 103.0 days
# Time Step: 104.0 days
# Time Step: 105.0 days
# Time Step: 106.0 days
# Time Step: 107.0 days
# Time Step: 108.0 days
# Time Step: 109.0 days
# Time Step: 110.0 days
# Time Step: 111.0 days
# Time Step: 112.0 days
# Time Step: 113.0 days
# Time Step: 114.0 days
# Time Step: 115.0 days
# Time Step: 116.0 days
# Time Step: 117.0 days
# Time Step: 118.0 days
# Time Step: 119.0 days
# Time Step: 120.0 days
# Time Step: 121.0 days
# Time Step: 122.0 days
# Time Step: 123.0 days
# Time Step: 124.0 days
# Time Step: 125.0 days
# Time Step: 126.0 days
# Time Step: 127.0 days
# Time Step: 128.0 days
# Time Step: 129.0 days
# Time Step: 130.0 days
# Time Step: 131.0 days
# Time Step: 132.0 days
# Time Step: 133.0 days
# Time Step: 134.0 days
# Time Step: 135.0 days
# Time Step: 136.0 days
# Time Step: 137.0 days
# Time Step: 138.0 days
# Time Step: 139.0 days
# Time Step: 140.0 days
# Time Step: 141.0 days
# Time Step: 142.0 days
# Time Step: 143.0 days
# Time Step: 144.0 days
# Time Step: 145.0 days
# Time Step: 146.0 days
# Time Step: 147.0 days
# Time Step: 148.0 days
# Time Step: 149.0 days
# Time Step: 150.0 days
# Time Step: 151.0 days
# Time Step: 152.0 days
# Time Step: 153.0 days
# Time Step: 154.0 days
# Time Step: 155.0 days
# Time Step: 156.0 days
# Time Step: 157.0 days
# Time Step: 158.0 days
# Time Step: 159.0 days
# Time Step: 160.0 days
# Time Step: 161.0 days
# Time Step: 162.0 days
# Time Step: 163.0 days
# Time Step: 164.0 days
# Time Step: 165.0 days
# Time Step: 166.0 days
# Time Step: 167.0 days
# Time Step: 168.0 days
# Time Step: 169.0 days
# Time Step: 170.0 days
# Time Step: 171.0 days
# Time Step: 172.0 days
# Time Step: 173.0 days
# Time Step: 174.0 days
# Time Step: 175.0 days
# Time Step: 176.0 days
# Time Step: 177.0 days
# Time Step: 178.0 days
# Time Step: 179.0 days
# Time Step: 180.0 days
# Time Step: 181.0 days
# Time Step: 182.0 days
# Time Step: 183.0 days
# Time Step: 184.0 days
# Time Step: 185.0 days
# Time Step: 186.0 days
# Time Step: 187.0 days
# Time Step: 188.0 days
# Time Step: 189.0 days
# Time Step: 190.0 days
# Time Step: 191.0 days
# Time Step: 192.0 days
# Time Step: 193.0 days
# Time Step: 194.0 days
# Time Step: 195.0 days
# Time Step: 196.0 days
# Time Step: 197.0 days
# Time Step: 198.0 days
# Time Step: 199.0 days
# Time Step: 200.0 days
# Time Step: 201.0 days
# Time Step: 202.0 days
# Time Step: 203.0 days
# Time Step: 204.0 days
# Time Step: 205.0 days
# Time Step: 206.0 days
# Time Step: 207.0 days
# Time Step: 208.0 days
# Time Step: 209.0 days
# Time Step: 210.0 days
# Time Step: 211.0 days
# Time Step: 212.0 days
# Time Step: 213.0 days
# Time Step: 214.0 days
# Time Step: 215.0 days
# Time Step: 216.0 days
# Time Step: 217.0 days
# Time Step: 218.0 days
# Time Step: 219.0 days
# Time Step: 220.0 days
# Time Step: 221.0 days
# Time Step: 222.0 days
# Time Step: 223.0 days
# Time Step: 224.0 days
# Time Step: 225.0 days
# Time Step: 226.0 days
# Time Step: 227.0 days
# Time Step: 228.0 days
# Time Step: 229.0 days
# Time Step: 230.0 days
# Time Step: 231.0 days
# Time Step: 232.0 days
# Time Step: 233.0 days
# Time Step: 234.0 days
# Time Step: 235.0 days
# Time Step: 236.0 days
# Time Step: 237.0 days
# Time Step: 238.0 days
# Time Step: 239.0 days
# Time Step: 240.0 days
# Time Step: 241.0 days
# Time Step: 242.0 days
# Time Step: 243.0 days
# Time Step: 244.0 days
# Time Step: 245.0 days
# Time Step: 246.0 days
# Time Step: 247.0 days
# Time Step: 248.0 days
# Time Step: 249.0 days
# Time Step: 250.0 days
# Time Step: 251.0 days
# Time Step: 252.0 days
# Time Step: 253.0 days
# Time Step: 254.0 days
# Time Step: 255.0 days
# Time Step: 256.0 days
# Time Step: 257.0 days
# Time Step: 258.0 days
# Time Step: 259.0 days
# Time Step: 260.0 days
# Time Step: 261.0 days
# Time Step: 262.0 days
# Time Step: 263.0 days
# Time Step: 264.0 days
# Time Step: 265.0 days
# Time Step: 266.0 days
# Time Step: 267.0 days
# Time Step: 268.0 days
# Time Step: 269.0 days
# Time Step: 270.0 days
# Time Step: 271.0 days
# Time Step: 272.0 days
# Time Step: 273.0 days
# Time Step: 274.0 days
# Time Step: 275.0 days
# Time Step: 276.0 days
# Time Step: 277.0 days
# Time Step: 278.0 days
# Time Step: 279.0 days
# Time Step: 280.0 days
# Time Step: 281.0 days
# Time Step: 282.0 days
# Time Step: 283.0 days
# Time Step: 284.0 days
# Time Step: 285.0 days
# Time Step: 286.0 days
# Time Step: 287.0 days
# Time Step: 288.0 days
# Time Step: 289.0 days
# Time Step: 290.0 days
# Time Step: 291.0 days
# Time Step: 292.0 days
# Time Step: 293.0 days
# Time Step: 294.0 days
# Time Step: 295.0 days
# Time Step: 296.0 days
# Time Step: 297.0 days
# Time Step: 298.0 days
# Time Step: 299.0 days
# Time Step: 300.0 days
# Time Step: 301.0 days
# Time Step: 302.0 days
# Time Step: 303.0 days
# Time Step: 304.0 days
# Time Step: 305.0 days
# Time Step: 306.0 days
# Time Step: 307.0 days
# Time Step: 308.0 days
# Time Step: 309.0 days
# Time Step: 310.0 days
# Time Step: 311.0 days
# Time Step: 312.0 days
# Time Step: 313.0 days
# Time Step: 314.0 days
# Time Step: 315.0 days
# Time Step: 316.0 days
# Time Step: 317.0 days
# Time Step: 318.0 days
# Time Step: 319.0 days
# Time Step: 320.0 days
# Time Step: 321.0 days
# Time Step: 322.0 days
# Time Step: 323.0 days
# Time Step: 324.0 days
# Time Step: 325.0 days
# Time Step: 326.0 days
# Time Step: 327.0 days
# Time Step: 328.0 days
# Time Step: 329.0 days
# Time Step: 330.0 days
# Time Step: 331.0 days
# Time Step: 332.0 days
# Time Step: 333.0 days
# Time Step: 334.0 days
# Time Step: 335.0 days
# Time Step: 336.0 days
# Time Step: 337.0 days
# Time Step: 338.0 days
# Time Step: 339.0 days
# Time Step: 340.0 days
# Time Step: 341.0 days
# Time Step: 342.0 days
# Time Step: 343.0 days
# Time Step: 344.0 days
# Time Step: 345.0 days
# Time Step: 346.0 days
# Time Step: 347.0 days
# Time Step: 348.0 days
# Time Step: 349.0 days
# Time Step: 350.0 days
# Time Step: 351.0 days
# Time Step: 352.0 days
# Time Step: 353.0 days
# Time Step: 354.0 days
# Time Step: 355.0 days
# Time Step: 356.0 days
# Time Step: 357.0 days
# Time Step: 358.0 days
# Time Step: 359.0 days
# Time Step: 360.0 days
# Time Step: 361.0 days
# Time Step: 362.0 days
# Time Step: 363.0 days
# Time Step: 364.0 days
# Time Step: 365.0 days

# %% [markdown]
# ## 8. Plot Head Distribution at Final Time Step

# %%
plt.figure(figsize=(8, 6))
plt.tricontourf(nodes[:, 0], nodes[:, 1], head_history[-1], 20, cmap='viridis')
plt.colorbar(label='Head (m)')
plt.xlabel('x (m)')
plt.ylabel('y (m)')
plt.title(f'Head Distribution at t = {time_history[-1]:.0f} days')
plt.show()

# %% [markdown]
# ## 9. Plot Head at a Specific Node Over Time

# %%
node_index = 100  # Choose a node
plt.figure(figsize=(8, 6))
plt.plot(time_history, head_history[:, node_index])
plt.xlabel('Time (days)')
plt.ylabel('Head (m)')
plt.title(f'Head at Node {node_index} over Time')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 10. Create 2D Animation of Head Distribution

# %%
fig, ax = plt.subplots()
cont = ax.tricontourf(nodes[:, 0], nodes[:, 1], head_history[0], 20, cmap='viridis')

def animate(i):
    ax.clear()
    ax.tricontourf(nodes[:, 0], nodes[:, 1], head_history[i], 20, cmap='viridis')
    ax.set_title(f'Head Distribution at t = {time_history[i]:.0f} days')

ani = matplotlib.animation.FuncAnimation(fig, animate, frames=len(head_history), interval=100)
ani.save('head_animation.gif', writer='pillow', fps=10)
plt.show()

# %% [markdown]
# ## 11. Create 3D Animation

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

def animate(i):
    ax.clear()
    ax.plot_trisurf(nodes[:, 0], nodes[:, 1], head_history[i], cmap='viridis')
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Head')

ani = animation.FuncAnimation(fig, animate, frames=len(head_history), interval=100)
ani.save('head_animation_3d.gif', writer='pillow', fps=10)
plt.show()
